# %%
import pandas as pd
import matplotlib.pyplot as plt
from soccerplots.radar_chart import Radar

# %%
#read in the data
df = pd.read_csv('./data/topGA.csv')
df.head()
# Out:
#              Player  Nation Pos     Age  MP  Starts  Min  90s  Gls  Ast  ...  \
# 0  Ryunosuke Sagara  jp JPN  MF  21-257  11       9  762  8.5    4    3  ...
# 1   Masato Nakayama  jp JPN  FW  32-084  11       7  542  6.0    3    1  ...
#
#    Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  G/SoT  Dist  PK.1  PKatt.1
# 0   4    4   100   0.47    0.47     1      1   NaN     0        0
# 1   3    3   100   0.50    0.50     1      1   NaN     0        0
#
# [2 rows x 32 columns]

# %%
#drop non-need-colomn
df = df.drop(['Nation','Pos','Age','MP','Starts','90s','Gls','Ast','Matches','G-PK','PK','PKatt','CrdR'],axis=1)
df
# Out:
#              Player  Min  G+A\n▼  CrdY  Gls.1  Ast.1   G+A  G-PK.1  G+A-PK  \
# 0  Ryunosuke Sagara  762       7     3   0.47   0.35  0.83    0.47    0.83
# 1   Masato Nakayama  542       4     0   0.50   0.17  0.66    0.50    0.66
#
#    Sh  SoT  SoT%  Sh/90  SoT/90  G/Sh  G/SoT  Dist  PK.1  PKatt.1
# 0   4    4   100   0.47    0.47     1      1   NaN     0        0
# 1   3    3   100   0.50    0.50     1      1   NaN     0        0

# %%
#get parameters
params = list(df.columns)
params = params[1:]
params
# Out:
# ['Min',
#  'G+A\n▼',
#  'CrdY',
#  'Gls.1',
#  'Ast.1',
#  'G+A',
#  'G-PK.1',
#  'G+A-PK',
#  'Sh',
#  'SoT',
#  'SoT%',
#  'Sh/90',
#  'SoT/90',
#  'G/Sh',
#  'G/SoT',
#  'Dist',
#  'PK.1',
#  'PKatt.1']

# %%
#add ranges to list of tuple pairs
ranges = []
a_values = []
b_values = []

for x in params:
    a = min(df[params][x])
    a = a - (a*.25)
    
    b = max(df[params][x])
    b = b + (b*.25)
    
    ranges.append((a,b))
    
for x in range(len(df['Player'])):
    if df['Player'][x] == 'Ryunosuke Sagara':
        a_values = df.iloc[x].values.tolist()
    if df['Player'][x] == 'Masato Nakayama':
        b_values = df.iloc[x].values.tolist()
        
a_values = a_values[1:]
b_values = b_values[1:]

values = [a_values,b_values]
values
# Out:
# [[762,
#   7,
#   3,
#   0.47,
#   0.35,
#   0.83,
#   0.47,
#   0.83,
#   4,
#   4,
#   100,
#   0.47,
#   0.47,
#   1,
#   1,
#   nan,
#   0,
#   0],
#  [542, 4, 0, 0.5, 0.17, 0.66, 0.5, 0.66, 3, 3, 100, 0.5, 0.5, 1, 1, nan, 0, 0]]

# %%
#title 
title = dict(
  title_name='Ryunosuke Sagara',
  title_color='#9B3647',
  subtitle_name="Vegalta Sendai",
  subtitle_color='#ABCDEF',
  title_name_2='Masato Nakayama',
  title_color_2='#3282b8',
  subtitle_name_2="Vegalta Sendai",
  subtitle_color_2='#ABCDEF',
  title_fontsize=18,
  subtitle_fontsize=15
)

endnote = '@gundgan_vamos\ndata via FBREF / Statsbomb'

# %%
radar = Radar(
  label_fontsize=12,
  range_fontsize=7.5,
  background_color="#121212",
  patch_color="#28252C",
  label_color="#FFFFFF",
  range_color="#FFFFFF"
)

fig,ax = radar.plot_radar(
  ranges=ranges,
  params=params,
  values=values,
  radar_color=['#9B3647', '#3282b8'],
  alphas=[.75,.6],
  title=title,
  image='./logo/vegaltasendai.png',
  image_coord=[0.495, 0.805, 0.04, 0.1],
  compare=True,
  filename="./output/Radar/topGA.jpg",
  endnote=endnote,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 10>()
#       1 radar = Radar(
#       2   label_fontsize=12,
#       3   range_fontsize=7.5,
#    (...)
#       7   range_color="#FFFFFF"
#       8 )
# ---> 10 fig,ax = radar.plot_radar(
#      11   ranges=ranges,
#      12   params=params,
#      13   values=values,
#      14   radar_color=['#9B3647', '#3282b8'],
#      15   alphas=[.75,.6],
#      16   title=title,
#      17   image='./logo/vegaltasendai.png',
#      18   image_coord=[0.495, 0.805, 0.04, 0.1],
#      19   compare=True,
#      20   filename="./output/Radar/topGA.jpg",
#      21   endnote=endnote,
#      22 )
#
# File ~/.local/lib/python3.8/site-packages/soccerplots/radar_chart.py:114, in Radar.plot_radar(self, ranges, params, values, radar_color, filename, dpi, title, alphas, compare, endnote, end_size, end_color, image, image_coord, figax, **kwargs)
#     111 value = values[i]
#     113 ## get vertices
# --> 114 vertices = self.__get_vertices(value, xy, range_values)
#     116 ## make the radar chart
#     117 ax = self.__plot_circles(ax=ax, radar_color=radar_color[i], vertices=vertices, alpha=alphas[i], compare=True)
#
# File ~/.local/lib/python3.8/site-packages/soccerplots/radar_chart.py:407, in Radar.__get_vertices(self, values, xy, range_values)
#     403         x_coord, y_coord = coord_list[0, 0], coord_list[0, 1]
#     405     else:
#     406         ## get indices between which the value is present
# --> 407         x_coord, y_coord = utils.get_indices_between(range_list=range_list, coord_list=coord_list, value=values[i], reverse=False)
#     409 ## add x-y coordinate in vertices as a list
#     410 vertices.append([x_coord, y_coord])
#
# File ~/.local/lib/python3.8/site-packages/soccerplots/utils.py:68, in get_indices_between(range_list, coord_list, value, reverse)
#      54 """
#      55 Function to get the x-coordinate and y-coordinate for the polygon vertex.
#      56
#    (...)
#      64     tuple: x-coordinate and y-coordinate value.
#      65 """
#      67 ## getting index value
# ---> 68 idx_1, idx_2 = get_index(array=range_list, value=value, reverse=reverse)
#      70 ## get x coordinate
#      71 x_coord = get_vertex_coord(
#      72     old_value=value,
#      73     old_min=range_list[idx_1],
#    (...)
#      76     new_max=coord_list[idx_2, 0]
#      77 )
#
# TypeError: cannot unpack non-iterable NoneType object
